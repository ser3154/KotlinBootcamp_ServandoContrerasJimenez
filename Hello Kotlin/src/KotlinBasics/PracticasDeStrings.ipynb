// %%
// Lea el código a continuación, intente seguir lo que hace y luego elija la respuesta correcta:
var welcomeMessage = "Hello and welcome to Kotlin"
when (welcomeMessage.length) {
    0 -> println("Nothing to say?")
    in 1..50 -> println("Perfect")
    else -> println("Too long!")
}
// Out:
// Perfect

// %%
// Cree tres variables de cadena para la trucha, el eglefino y el pargo.
val trout = "trout"
var haddock = "haddock"
var snapper = "snapper"
println("I like to eat $trout and $snapper, but not a big fan of $haddock.")
// Out:
// I like to eat trout and snapper, but not a big fan of haddock.

// %%
//cuando las declaraciones en Kotlin son como las declaraciones case o switch en otros lenguajes.
val fishName = "fishName"
when(fishName.length){
    0 -> println("Fish name cannot be empty")
    in 3..12 -> println("Good fish name")
    else -> println("OK fish name")
}
// Out:
// Good fish name
