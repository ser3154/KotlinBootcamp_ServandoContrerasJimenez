// %%
// Anteriormente, creamos y filtramos una lista de especias. Las especias se representan mucho mejor como objetos que como simples cadenas. Al ser objetos, podemos usarlas para diversas actividades, como cocinar.
class SimpleSpice() {
    val name = "curry"
    val spiciness = "mild"
    val heat: Int
        get() { return 5 }
}

val simpleSpice = SimpleSpice()
println("${simpleSpice.name} ${simpleSpice.heat}")
// Out:
// curry 5
