// %%
fun printHello () {
    println ("Hello World")
}

printHello()
// Out:
// Hello World

// %%
//tarea 1 cuantos peces hay?
2.plus(71).plus(233).minus(13).div(30).plus(1)
// Out:
// 10

// %%
//tarea 2 RaibowColor
var rainbowColor = "red"
rainbowColor = "blue"
val blackColor = "black"
//blackColor = "white" // Error

// %%
//Tarea 3 Cambiar RainbowColor a null
var greenColor = null
var blueColor: Int? = null

// %%
//Tarea 4 Crea una lista con dos elementos nulos
listOf(null,null)
var list: List<String?> = listOf(null, null)
var list2: List<String>? = null

// %%
//Tarea 5 Cree una variable entera que acepte valores NULL
var nullTest: Int? = null
println(nullTest?.inc() ?:0)
// Out:
// 0
